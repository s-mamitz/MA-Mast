# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting SPARQLWrapper==2.0.0
#   Downloading SPARQLWrapper-2.0.0-py3-none-any.whl (28 kB)
# Collecting networkx==3.4.2
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 1.7/1.7 MB 26.3 MB/s eta 0:00:00
# Collecting pyvis==0.3.2
#   Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 756.0/756.0 kB 61.8 MB/s eta 0:00:00
# Collecting ipywidgets==8.1.5
#   Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━ 139.8/139.8 kB 8.8 MB/s eta 0:00:00
# Collecting wordcloud==1.9.4
#   Downloading wordcloud-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 511.1/511.1 kB 77.2 MB/s eta 0:00:00
# Collecting bs4==0.0.2
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Collecting ace_tools==0.0
#   Downloading ace_tools-0.0-py3-none-any.whl (1.1 kB)
# Collecting rdflib>=6.1.1
#   Downloading rdflib-7.1.3-py3-none-any.whl (564 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━ 564.9/564.9 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: jinja2>=2.9.6 in /root/venv/lib/python3.10/site-packages (from pyvis==0.3.2->-r ./requirements.txt (line 3)) (3.1.5)
# Requirement already satisfied: ipython>=5.3.0 in /root/venv/lib/python3.10/site-packages (from pyvis==0.3.2->-r ./requirements.txt (line 3)) (8.32.0)
# Collecting jsonpickle>=1.4.1
#   Downloading jsonpickle-4.0.2-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 46.3/46.3 kB 13.0 MB/s eta 0:00:00
# Collecting widgetsnbextension~=4.0.12
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 2.3/2.3 MB 124.9 MB/s eta 0:00:00
# Requirement already satisfied: comm>=0.1.3 in /toolkit-cache/0.2.9/python3.10/kernel-libs/lib/python3.10/site-packages (from ipywidgets==8.1.5->-r ./requirements.txt (line 4)) (0.2.2)
# Collecting jupyterlab-widgets~=3.0.12
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 214.4/214.4 kB 45.0 MB/s eta 0:00:00
# Requirement already satisfied: traitlets>=4.3.1 in /root/venv/lib/python3.10/site-packages (from ipywidgets==8.1.5->-r ./requirements.txt (line 4)) (5.14.3)
# Requirement already satisfied: matplotlib in /root/venv/lib/python3.10/site-packages (from wordcloud==1.9.4->-r ./requirements.txt (line 5)) (3.6.3)
# Requirement already satisfied: pillow in /root/venv/lib/python3.10/site-packages (from wordcloud==1.9.4->-r ./requirements.txt (line 5)) (11.1.0)
# Requirement already satisfied: numpy>=1.6.1 in /root/venv/lib/python3.10/site-packages (from wordcloud==1.9.4->-r ./requirements.txt (line 5)) (1.25.2)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.13.3-py3-none-any.whl (186 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 186.0/186.0 kB 39.0 MB/s eta 0:00:00
# Requirement already satisfied: pexpect>4.3 in /root/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis==0.3.2->-r ./requirements.txt (line 3)) (4.9.0)
# Requirement already satisfied: stack_data in /root/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis==0.3.2->-r ./requirements.txt (line 3)) (0.6.3)
# Requirement already satisfied: matplotlib-inline in /root/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis==0.3.2->-r ./requirements.txt (line 3)) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /root/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis==0.3.2->-r ./requirements.txt (line 3)) (3.0.50)
# Requirement already satisfied: typing_extensions>=4.6 in /root/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis==0.3.2->-r ./requirements.txt (line 3)) (4.12.2)
# Requirement already satisfied: jedi>=0.16 in /root/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis==0.3.2->-r ./requirements.txt (line 3)) (0.17.2)
# Requirement already satisfied: decorator in /root/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis==0.3.2->-r ./requirements.txt (line 3)) (5.1.1)
# Requirement already satisfied: exceptiongroup in /root/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis==0.3.2->-r ./requirements.txt (line 3)) (1.2.2)
# Requirement already satisfied: pygments>=2.4.0 in /root/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis==0.3.2->-r ./requirements.txt (line 3)) (2.19.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/venv/lib/python3.10/site-packages (from jinja2>=2.9.6->pyvis==0.3.2->-r ./requirements.txt (line 3)) (3.0.2)
# Requirement already satisfied: isodate<1.0.0,>=0.7.2 in /root/venv/lib/python3.10/site-packages (from rdflib>=6.1.1->SPARQLWrapper==2.0.0->-r ./requirements.txt (line 1)) (0.7.2)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /root/venv/lib/python3.10/site-packages (from rdflib>=6.1.1->SPARQLWrapper==2.0.0->-r ./requirements.txt (line 1)) (3.2.1)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.6-py3-none-any.whl (36 kB)
# Requirement already satisfied: cycler>=0.10 in /root/venv/lib/python3.10/site-packages (from matplotlib->wordcloud==1.9.4->-r ./requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.10/site-packages (from matplotlib->wordcloud==1.9.4->-r ./requirements.txt (line 5)) (4.56.0)
# Requirement already satisfied: packaging>=20.0 in /root/venv/lib/python3.10/site-packages (from matplotlib->wordcloud==1.9.4->-r ./requirements.txt (line 5)) (24.2)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.10/site-packages (from matplotlib->wordcloud==1.9.4->-r ./requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /root/venv/lib/python3.10/site-packages (from matplotlib->wordcloud==1.9.4->-r ./requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /root/venv/lib/python3.10/site-packages (from matplotlib->wordcloud==1.9.4->-r ./requirements.txt (line 5)) (1.4.8)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /root/venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis==0.3.2->-r ./requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /root/venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis==0.3.2->-r ./requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: wcwidth in /root/venv/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis==0.3.2->-r ./requirements.txt (line 3)) (0.2.13)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud==1.9.4->-r ./requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /root/venv/lib/python3.10/site-packages (from stack_data->ipython>=5.3.0->pyvis==0.3.2->-r ./requirements.txt (line 3)) (2.2.0)
# Requirement already satisfied: pure-eval in /root/venv/lib/python3.10/site-packages (from stack_data->ipython>=5.3.0->pyvis==0.3.2->-r ./requirements.txt (line 3)) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in /root/venv/lib/python3.10/site-packages (from stack_data->ipython>=5.3.0->pyvis==0.3.2->-r ./requirements.txt (line 3)) (3.0.0)
# Installing collected packages: ace_tools, widgetsnbextension, soupsieve, rdflib, networkx, jupyterlab-widgets, jsonpickle, SPARQLWrapper, beautifulsoup4, wordcloud, pyvis, ipywidgets, bs4
# Successfully installed SPARQLWrapper-2.0.0 ace_tools-0.0 beautifulsoup4-4.13.3 bs4-0.0.2 ipywidgets-8.1.5 jsonpickle-4.0.2 jupyterlab-widgets-3.0.13 networkx-3.4.2 pyvis-0.3.2 rdflib-7.1.3 soupsieve-2.6 widgetsnbextension-4.0.13 wordcloud-1.9.4
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
